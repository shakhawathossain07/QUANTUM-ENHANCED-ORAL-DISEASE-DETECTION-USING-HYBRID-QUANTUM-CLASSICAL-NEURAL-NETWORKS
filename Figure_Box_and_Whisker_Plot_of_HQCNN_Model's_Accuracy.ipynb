# %%
# Md. Shakhawat Hossain
# Bachelor of Science in Computer Science and Engineering (BSCSE)
# Department of Electrical and Computer Engineering
# North South University
# Plot # 15, Block # B, Bashundhara
# Dhaka – 1229, Bangladesh
# Gmail: shakhawat.hossain07.edu@gmail.com

import matplotlib.pyplot as plt
import numpy as np

# Accuracy values for the 5 HQCNN models from the table
accuracies = [88.73, 64.42, 65.81, 65.92, 58.92]

# Create a boxplot with color and grid
plt.figure(figsize=(6, 6))
plt.boxplot(accuracies, vert=False, patch_artist=True,
            boxprops=dict(facecolor='skyblue', color='blue'),
            medianprops=dict(color='red', linewidth=2),
            whiskerprops=dict(color='green', linewidth=2),
            capprops=dict(color='black', linewidth=2),
            labels=['HQCNN'])  # Set the label to 'HQCNN'

# Adding grid
plt.grid(True, linestyle='--', linewidth=0.7)

# Title and labels
plt.title('Box and Whisker Plot of HQCNN Model Accuracy for Binary and Senary Classification', fontsize=14)
plt.xlabel('Accuracy (%)', fontsize=12)

# Display the plot
plt.show()
# Out:
# <ipython-input-3-e1675fafa302>:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(accuracies, vert=False, patch_artist=True,
