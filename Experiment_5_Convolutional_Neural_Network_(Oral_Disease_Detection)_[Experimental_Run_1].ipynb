# %%
# Mount Google Drive (for Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import required packages
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score

# %%
# Define parameters and dataset directory
batch_size = 32
img_height, img_width = 32, 32
dataset_dir = '/content/drive/MyDrive/Colab Notebooks/data'  # Update path if needed

# %%
# Load the raw training and test datasets using image_dataset_from_directory
raw_train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

raw_test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

# Capture the class names for visualization later
class_names = raw_train_dataset.class_names
# Out:
# Found 3645 files belonging to 2 classes.
# Using 2916 files for training.
# Found 3645 files belonging to 2 classes.
# Using 729 files for validation.

# %%
# Define a function to introduce heavy label noise (70%) and normalize the images.
def add_label_noise(x, y, noise_factor=0.7):
    # Create a noise tensor for each label in the batch
    noise = tf.random.uniform(shape=tf.shape(y), minval=0, maxval=1, dtype=tf.float32)
    # Generate random labels for the entire batch (matching the shape of y)
    random_labels = tf.random.uniform(shape=tf.shape(y), minval=0, maxval=2, dtype=tf.int64)
    # Replace with random label when noise < noise_factor, else keep the original label.
    noisy_y = tf.where(noise < noise_factor, random_labels, tf.cast(y, tf.int64))
    return x / 255.0, noisy_y

# Apply label noise to the training dataset; keep test dataset clean (only normalization)
train_dataset = raw_train_dataset.map(lambda x, y: add_label_noise(x, y, noise_factor=0.7))
test_dataset = raw_test_dataset.map(lambda x, y: (x / 255.0, y))

# %%
# Define a simplified CNN architecture with dropout to reduce capacity
model = models.Sequential([
    layers.Conv2D(16, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Flatten(),
    layers.Dense(16, activation='relu'),
    layers.Dense(2)  # For 2 classes (e.g., "Calculus" and "Gingivitis")
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │        18,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,570 (92.07 KB)
#  Trainable params: 23,570 (92.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model (using 1 epoch here for demonstration; adjust to 80 epochs as needed)
history = model.fit(train_dataset, epochs=80, validation_data=test_dataset)
# Out:
# Epoch 1/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 414s 4s/step - accuracy: 0.5447 - loss: 0.7016 - val_accuracy: 0.6543 - val_loss: 0.6803
# Epoch 2/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 50s 205ms/step - accuracy: 0.5098 - loss: 0.6951 - val_accuracy: 0.6543 - val_loss: 0.6809
# Epoch 3/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 227ms/step - accuracy: 0.5318 - loss: 0.6936 - val_accuracy: 0.6543 - val_loss: 0.6832
# Epoch 4/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 39s 203ms/step - accuracy: 0.5382 - loss: 0.6908 - val_accuracy: 0.6543 - val_loss: 0.6837
# Epoch 5/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 187ms/step - accuracy: 0.5365 - loss: 0.6904 - val_accuracy: 0.6543 - val_loss: 0.6860
# Epoch 6/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 194ms/step - accuracy: 0.5444 - loss: 0.6900 - val_accuracy: 0.6543 - val_loss: 0.6796
# Epoch 7/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 217ms/step - accuracy: 0.5323 - loss: 0.6914 - val_accuracy: 0.6543 - val_loss: 0.6835
# Epoch 8/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 193ms/step - accuracy: 0.5282 - loss: 0.6912 - val_accuracy: 0.6543 - val_loss: 0.6807
# Epoch 9/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 198ms/step - accuracy: 0.5259 - loss: 0.6923 - val_accuracy: 0.6543 - val_loss: 0.6823
# Epoch 10/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 223ms/step - accuracy: 0.5482 - loss: 0.6893 - val_accuracy: 0.6543 - val_loss: 0.6735
# Epoch 11/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 39s
80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 199ms/step - accuracy: 0.5586 - loss: 0.6846 - val_accuracy: 0.7215 - val_loss: 0.6396
# Epoch 66/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 171ms/step - accuracy: 0.5472 - loss: 0.6861 - val_accuracy: 0.7133 - val_loss: 0.6351
# Epoch 67/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - accuracy: 0.5528 - loss: 0.6840 - val_accuracy: 0.7243 - val_loss: 0.6292
# Epoch 68/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 197ms/step - accuracy: 0.5574 - loss: 0.6826 - val_accuracy: 0.7284 - val_loss: 0.6390
# Epoch 69/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.5744 - loss: 0.6806 - val_accuracy: 0.7037 - val_loss: 0.6254
# Epoch 70/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.5709 - loss: 0.6824 - val_accuracy: 0.7380 - val_loss: 0.6277
# Epoch 71/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - accuracy: 0.5944 - loss: 0.6743 - val_accuracy: 0.7243 - val_loss: 0.6391
# Epoch 72/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 171ms/step - accuracy: 0.5789 - loss: 0.6729 - val_accuracy: 0.7229 - val_loss: 0.6306
# Epoch 73/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.5624 - loss: 0.6868 - val_accuracy: 0.7119 - val_loss: 0.6316
# Epoch 74/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - accuracy: 0.5690 - loss: 0.6817 - val_accuracy: 0.7353 - val_loss: 0.6402
# Epoch 75/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 197ms/step - accuracy: 0.5903 - loss: 0.6757 - val_accuracy: 0.7270 - val_loss: 0.6238
# Epoch 76/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 167ms/step - accuracy: 0.5731 - loss: 0.6799 - val_accuracy: 0.7325 - val_loss: 0.6479
# Epoch 77/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - accuracy: 0.5635 - loss: 0.6823 - val_accuracy: 0.7257 - val_loss: 0.6191
# Epoch 78/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 167ms/step - accuracy: 0.5515 - loss: 0.6851 - val_accuracy: 0.7421 - val_loss: 0.6469
# Epoch 79/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 198ms/step - accuracy: 0.5543 - loss: 0.6845 - val_accuracy: 0.7298 - val_loss: 0.6240
# Epoch 80/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 170ms/step - accuracy: 0.5481 - loss: 0.6886 - val_accuracy: 0.7257 - val_loss: 0.6336

# %%
# Plot training and validation accuracy over epochs
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Evaluate the model using the built-in evaluate() method
test_loss, test_acc = model.evaluate(test_dataset, verbose=2)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)

# Calculate additional evaluation metrics: Accuracy, Macro-F1, Precision, Recall, AUROC.
all_labels = []
all_preds = []
all_probs = []

for images, labels in test_dataset:
    logits = model.predict(images)
    # Convert logits to probabilities using softmax
    probs = tf.nn.softmax(logits, axis=1).numpy()
    preds = np.argmax(probs, axis=1)

    all_labels.extend(labels.numpy())
    all_preds.extend(preds)
    all_probs.extend(probs)

all_labels = np.array(all_labels)
all_preds = np.array(all_preds)
all_probs = np.array(all_probs)

accuracy_val = accuracy_score(all_labels, all_preds)
macro_f1 = f1_score(all_labels, all_preds, average='macro')
precision_val = precision_score(all_labels, all_preds, average='macro')
recall_val = recall_score(all_labels, all_preds, average='macro')
# For AUROC, use the probability for the positive class (assumed index 1)
auroc_val = roc_auc_score(all_labels, all_probs[:, 1])

print(f"\nCalculated Test Accuracy: {accuracy_val:.4f}")
print(f"Macro F1 Score: {macro_f1:.4f}")
print(f"Precision: {precision_val:.4f}")
print(f"Recall: {recall_val:.4f}")
print(f"AUROC: {auroc_val:.4f}")
# Out:
# 23/23 - 4s - 165ms/step - accuracy: 0.7257 - loss: 0.6336
# Test Loss: 0.6335636973381042
# Test Accuracy: 0.7256515622138977
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#
# Calculated Test Accuracy: 0.7257
# Macro F1 Score: 0.5903
# Precision: 0.8273
# Recall: 0.6060
# AUROC: 0.8113
