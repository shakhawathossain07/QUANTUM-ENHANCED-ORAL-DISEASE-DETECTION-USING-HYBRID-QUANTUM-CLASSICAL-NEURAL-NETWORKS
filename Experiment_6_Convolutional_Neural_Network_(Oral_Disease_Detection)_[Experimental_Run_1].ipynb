# %%
# Mount Google Drive (for Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import required packages
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score

# %%
# Define parameters and dataset directory
batch_size = 32
img_height, img_width = 32, 32
dataset_dir = '/content/drive/MyDrive/Colab Notebooks/data'  # Update path if needed

# %%
# Load the raw training and test datasets using image_dataset_from_directory
raw_train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

raw_test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

# Capture the class names for visualization later
class_names = raw_train_dataset.class_names
# Out:
# Found 3645 files belonging to 2 classes.
# Using 2916 files for training.
# Found 3645 files belonging to 2 classes.
# Using 729 files for validation.

# %%
# Define a function to introduce heavy label noise (70%) and normalize the images.
def add_label_noise(x, y, noise_factor=0.7):
    # Create a noise tensor for each label in the batch
    noise = tf.random.uniform(shape=tf.shape(y), minval=0, maxval=1, dtype=tf.float32)
    # Generate random labels for the entire batch (matching the shape of y)
    random_labels = tf.random.uniform(shape=tf.shape(y), minval=0, maxval=2, dtype=tf.int64)
    # Replace with random label when noise < noise_factor, else keep the original label.
    noisy_y = tf.where(noise < noise_factor, random_labels, tf.cast(y, tf.int64))
    return x / 255.0, noisy_y

# Apply label noise to the training dataset; keep test dataset clean (only normalization)
train_dataset = raw_train_dataset.map(lambda x, y: add_label_noise(x, y, noise_factor=0.7))
test_dataset = raw_test_dataset.map(lambda x, y: (x / 255.0, y))

# %%
# Define a simplified CNN architecture with dropout to reduce capacity
model = models.Sequential([
    layers.Conv2D(16, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Flatten(),
    layers.Dense(16, activation='relu'),
    layers.Dense(2)  # For 2 classes (e.g., "Calculus" and "Gingivitis")
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │        18,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,570 (92.07 KB)
#  Trainable params: 23,570 (92.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model (using 1 epoch here for demonstration; adjust to 80 epochs as needed)
history = model.fit(train_dataset, epochs=80, validation_data=test_dataset)
# Out:
# Epoch 1/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 403s 4s/step - accuracy: 0.5263 - loss: 0.7071 - val_accuracy: 0.6529 - val_loss: 0.6829
# Epoch 2/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 56s 171ms/step - accuracy: 0.5341 - loss: 0.6920 - val_accuracy: 0.6543 - val_loss: 0.6831
# Epoch 3/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 171ms/step - accuracy: 0.5278 - loss: 0.6918 - val_accuracy: 0.6543 - val_loss: 0.6831
# Epoch 4/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 200ms/step - accuracy: 0.5580 - loss: 0.6883 - val_accuracy: 0.6543 - val_loss: 0.6849
# Epoch 5/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 199ms/step - accuracy: 0.5454 - loss: 0.6870 - val_accuracy: 0.6543 - val_loss: 0.6719
# Epoch 6/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 198ms/step - accuracy: 0.5735 - loss: 0.6830 - val_accuracy: 0.5089 - val_loss: 0.6925
# Epoch 7/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 168ms/step - accuracy: 0.5436 - loss: 0.6900 - val_accuracy: 0.6543 - val_loss: 0.6801
# Epoch 8/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 166ms/step - accuracy: 0.5398 - loss: 0.6891 - val_accuracy: 0.6543 - val_loss: 0.6732
# Epoch 9/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 165ms/step - accuracy: 0.5406 - loss: 0.6901 - val_accuracy: 0.6543 - val_loss: 0.6802
# Epoch 10/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 163ms/step - accuracy: 0.5345 - loss: 0.6910 - val_accuracy: 0.6543 - val_loss: 0.6569
# Epoch 11/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 164ms/step - accuracy: 0.5502 - loss: 0.6920 - val_accuracy: 0.6543 - val_loss: 0.6777
# Epoch 12/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - accuracy: 0.5600 - loss: 0.6857 - val_accuracy: 0.6543 - val_loss: 0.6647
# Epoch 13/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 166ms/step - accuracy: 0.5487 - loss: 0.6858 - val_accuracy: 0.6543 - val_loss: 0.6805
# Epoch 14/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.5305 - loss: 0.6907 - val_accuracy: 0.6708 - val_loss: 0.6825
# Epoch 15/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 165ms/step - accuracy: 0.5348 - loss: 0.6912 - val_accuracy: 0.6543 - val_loss: 0.6692
# Epoch 16/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 197ms/step - accuracy: 0.5457 - loss: 0.6892 - val_accuracy: 0.6543 - val_loss: 0.6801
# Epoch 17/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 184ms/step - accuracy: 0.5337 - loss: 0.6899 - val_accuracy: 0.6543 - val_loss: 0.6674
# Epoch 18/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.5522 - loss: 0.6878 - val_accuracy: 0.6543 - val_loss: 0.6739
# Epoch 19/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 204ms/step - accuracy: 0.5390 - loss: 0.6886 - val_accuracy: 0.6543 - val_loss: 0.6666
# Epoch 20/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 199ms/step - accuracy: 0.5261 - loss: 0.6910 - val_accuracy: 0.6543 - val_loss: 0.6756
# Epoch 21/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 186ms/step - accuracy: 0.5481 - loss: 0.6864 - val_accuracy: 0.6543 - val_loss: 0.6764
# Epoch 22/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 169ms/step - accuracy: 0.5287 - loss: 0.6889 - val_accuracy: 0.6543 - val_loss: 0.6648
# Epoch 23/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 197ms/step - accuracy: 0.5386 - loss: 0.6884 - val_accuracy: 0.6598 - val_loss: 0.6735
# Epoch 24/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - accuracy: 0.5577 - loss: 0.6882 - val_accuracy: 0.6557 - val_loss: 0.6756
# Epoch 25/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 168ms/step - accuracy: 0.5564 - loss: 0.6854 - val_accuracy: 0.6790 - val_loss: 0.6671
# Epoch 26/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - accuracy: 0.5341 - loss: 0.6909 - val_accuracy: 0.6598 - val_loss: 0.6750
# Epoch 27/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.5557 - loss: 0.6867 - val_accuracy: 0.6612 - val_loss: 0.6773
# Epoch 28/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.5531 - loss: 0.6876 - val_accuracy: 0.6639 - val_loss: 0.6668
# Epoch 29/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - accuracy: 0.5507 - loss: 0.6872 - val_accuracy: 0.6941 - val_loss: 0.6707
# Epoch 30/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - accuracy: 0.5450 - loss: 0.6871 - val_accuracy: 0.6694 - val_loss: 0.6682
# Epoch 31/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 198ms/step - accuracy: 0.5448 - loss: 0.6871 - val_accuracy: 0.6735 - val_loss: 0.6546
# Epoch 32/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.5570 - loss: 0.6889 - val_accuracy: 0.6653 - val_loss: 0.6652
# Epoch 33/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - accuracy: 0.5518 - loss: 0.6863 - val_accuracy: 0.6955 - val_loss: 0.6563
# Epoch 34/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 202ms/step - accuracy: 0.5433 - loss: 0.6879 - val_accuracy: 0.6914 - val_loss: 0.6709
# Epoch 35/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 200ms/step - accuracy: 0.5822 - loss: 0.6811 - val_accuracy: 0.6955 - val_loss: 0.6650
# Epoch 36/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 204ms/step - accuracy: 0.5529 - loss: 0.6859 - val_accuracy: 0.6886 - val_loss: 0.6467
# Epoch 37/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 173ms/step - accuracy: 0.5399 - loss: 0.6894 - val_accuracy: 0.6886 - val_loss: 0.6578
# Epoch 38/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 196ms/step - accuracy: 0.5286 - loss: 0.6898 - val_accuracy: 0.6804 - val_loss: 0.6656
# Epoch 39/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - accuracy: 0.5380 - loss: 0.6901 - val_accuracy: 0.6749 - val_loss: 0.6659
# Epoch 40/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 174ms/step - accuracy: 0.5563 - loss: 0.6861 - val_accuracy: 0.7010 - val_loss: 0.6569
# Epoch 41/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 200ms/step - accuracy: 0.5436 - loss: 0.6877 - val_accuracy: 0.7023 - val_loss: 0.6627
# Epoch 42/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 181ms/step - accuracy: 0.5482 - loss: 0.6878 - val_accuracy: 0.7010 - val_loss: 0.6656
# Epoch 43/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 199ms/step - accuracy: 0.5699 - loss: 0.6829 - val_accuracy: 0.7037 - val_loss: 0.6535
# Epoch 44/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 178ms/step - accuracy: 0.5713 - loss: 0.6811 - val_accuracy: 0.7051 - val_loss: 0.6648
# Epoch 45/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 206ms/step - accuracy: 0.5432 - loss: 0.6893 - val_accuracy: 0.7106 - val_loss: 0.6569
# Epoch 46/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 201ms/step - accuracy: 0.5529 - loss: 0.6857 - val_accuracy: 0.7160 - val_loss: 0.6574
# Epoch 47/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 25s 252ms/step - accuracy: 0.5590 - loss: 0.6845 - val_accuracy: 0.7147 - val_loss: 0.6466
# Epoch 48/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 203ms/step - accuracy: 0.5482 - loss: 0.6926 - val_accuracy: 0.7229 - val_loss: 0.6521
# Epoch 49/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 182ms/step - accuracy: 0.5533 - loss: 0.6859 - val_accuracy: 0.7106 - val_loss: 0.6425
# Epoch 50/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 200ms/step - accuracy: 0.5553 - loss: 0.6863 - val_accuracy: 0.7160 - val_loss: 0.6570
# Epoch 51/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 175ms/step - accuracy: 0.5401 - loss: 0.6903 - val_accuracy: 0.7160 - val_loss: 0.6591
# Epoch 52/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 196ms/step - accuracy: 0.5777 - loss: 0.6823 - val_accuracy: 0.7188 - val_loss: 0.6531
# Epoch 53/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 199ms/step - accuracy: 0.5529 - loss: 0.6875 - val_accuracy: 0.7215 - val_loss: 0.6502
# Epoch 54/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 197ms/step - accuracy: 0.5482 - loss: 0.6863 - val_accuracy: 0.7119 - val_loss: 0.6522
# Epoch 55/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - accuracy: 0.5420 - loss: 0.6881 - val_accuracy: 0.7078 - val_loss: 0.6463
# Epoch 56/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - accuracy: 0.5747 - loss: 0.6779 - val_accuracy: 0.7270 - val_loss: 0.6426
# Epoch 57/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 171ms/step - accuracy: 0.5698 - loss: 0.6770 - val_accuracy: 0.7243 - val_loss: 0.6272
# Epoch 58/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 177ms/step - accuracy: 0.5573 - loss: 0.6868 - val_accuracy: 0.7174 - val_loss: 0.6435
# Epoch 59/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 24s 217ms/step - accuracy: 0.5516 - loss: 0.6847 - val_accuracy: 0.7174 - val_loss: 0.6488
# Epoch 60/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 174ms/step - accuracy: 0.5548 - loss: 0.6855 - val_accuracy: 0.7202 - val_loss: 0.6559
# Epoch 61/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 170ms/step - accuracy: 0.5737 - loss: 0.6827 - val_accuracy: 0.7243 - val_loss: 0.6361
# Epoch 62/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 171ms/step - accuracy: 0.5646 - loss: 0.6820 - val_accuracy: 0.7119 - val_loss: 0.6414
# Epoch 63/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 199ms/step - accuracy: 0.5650 - loss: 0.6804 - val_accuracy: 0.6914 - val_loss: 0.6340
# Epoch 64/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 177ms/step - accuracy: 0.5515 - loss: 0.6887 - val_accuracy: 0.7023 - val_loss: 0.6697
# Epoch 65/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 172ms/step - accuracy: 0.5554 - loss: 0.6839 - val_accuracy: 0.7119 - val_loss: 0.6630
# Epoch 66/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 169ms/step - accuracy: 0.5626 - loss: 0.6822 - val_accuracy: 0.7119 - val_loss: 0.6452
# Epoch 67/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 168ms/step - accuracy: 0.5550 - loss: 0.6814 - val_accuracy: 0.7160 - val_loss: 0.6371
# Epoch 68/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 201ms/step - accuracy: 0.5689 - loss: 0.6834 - val_accuracy: 0.7270 - val_loss: 0.6378
# Epoch 69/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 194ms/step - accuracy: 0.5679 - loss: 0.6857 - val_accuracy: 0.7215 - val_loss: 0.6448
# Epoch 70/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 175ms/step - accuracy: 0.5679 - loss: 0.6825 - val_accuracy: 0.7051 - val_loss: 0.6601
# Epoch 71/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.5728 - loss: 0.6829 - val_accuracy: 0.7051 - val_loss: 0.6297
# Epoch 72/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - accuracy: 0.5599 - loss: 0.6845 - val_accuracy: 0.7174 - val_loss: 0.6430
# Epoch 73/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 197ms/step - accuracy: 0.5476 - loss: 0.6886 - val_accuracy: 0.7188 - val_loss: 0.6416
# Epoch 74/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 196ms/step - accuracy: 0.5656 - loss: 0.6779 - val_accuracy: 0.7229 - val_loss: 0.6250
# Epoch 75/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 196ms/step - accuracy: 0.5748 - loss: 0.6793 - val_accuracy: 0.7325 - val_loss: 0.6418
# Epoch 76/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 201ms/step - accuracy: 0.5716 - loss: 0.6787 - val_accuracy: 0.7202 - val_loss: 0.6365
# Epoch 77/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 199ms/step - accuracy: 0.5609 - loss: 0.6822 - val_accuracy: 0.7202 - val_loss: 0.6436
# Epoch 78/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 197ms/step - accuracy: 0.5493 - loss: 0.6870 - val_accuracy: 0.7106 - val_loss: 0.6537
# Epoch 79/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 173ms/step - accuracy: 0.5690 - loss: 0.6839 - val_accuracy: 0.7380 - val_loss: 0.6477
# Epoch 80/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 171ms/step - accuracy: 0.5633 - loss: 0.6853 - val_accuracy: 0.7215 - val_loss: 0.6407

# %%
# Plot training and validation accuracy over epochs
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Evaluate the model using the built-in evaluate() method
test_loss, test_acc = model.evaluate(test_dataset, verbose=2)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)

# Calculate additional evaluation metrics: Accuracy, Macro-F1, Precision, Recall, AUROC.
all_labels = []
all_preds = []
all_probs = []

for images, labels in test_dataset:
    logits = model.predict(images)
    # Convert logits to probabilities using softmax
    probs = tf.nn.softmax(logits, axis=1).numpy()
    preds = np.argmax(probs, axis=1)

    all_labels.extend(labels.numpy())
    all_preds.extend(preds)
    all_probs.extend(probs)

all_labels = np.array(all_labels)
all_preds = np.array(all_preds)
all_probs = np.array(all_probs)

accuracy_val = accuracy_score(all_labels, all_preds)
macro_f1 = f1_score(all_labels, all_preds, average='macro')
precision_val = precision_score(all_labels, all_preds, average='macro')
recall_val = recall_score(all_labels, all_preds, average='macro')
# For AUROC, use the probability for the positive class (assumed index 1)
auroc_val = roc_auc_score(all_labels, all_probs[:, 1])

print(f"\nCalculated Test Accuracy: {accuracy_val:.4f}")
print(f"Macro F1 Score: {macro_f1:.4f}")
print(f"Precision: {precision_val:.4f}")
print(f"Recall: {recall_val:.4f}")
print(f"AUROC: {auroc_val:.4f}")
# Out:
# 23/23 - 3s - 109ms/step - accuracy: 0.7215 - loss: 0.6407
# Test Loss: 0.6406508088111877
# Test Accuracy: 0.7215363383293152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
# Calculated Test Accuracy: 0.7215
# Macro F1 Score: 0.5981
# Precision: 0.7722
# Recall: 0.6085
# AUROC: 0.7831
