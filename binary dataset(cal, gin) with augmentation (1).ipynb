# %%
# ─────────────────────────────────────────────────────────────
# 0. Environment – upgrade (Colab users) and imports
# ─────────────────────────────────────────────────────────────
# !pip -q install --upgrade "qiskit~=1.0" "qiskit-aer"

import math, os, random, numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

import torch, torch.nn as nn, torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import qiskit
from qiskit.circuit import QuantumCircuit as QiskitCircuit, Parameter
from qiskit import transpile
from qiskit_aer import Aer

SEED = 42
torch.manual_seed(SEED); np.random.seed(SEED); random.seed(SEED)

# ─────────────────────────────────────────────────────────────
# 1. Paths & global hyper-parameters
# ─────────────────────────────────────────────────────────────
DATA_DIR   = Path('/content/drive/MyDrive/Colab Notebooks/data')  # expects data/calculus/ and data/gingivitis/
IMG_SIZE   = 32     # images resized to 32×32
BATCH_SIZE = 16
EPOCHS     = 70
LR         = 1e-3
SHOTS      = 100
SHIFT      = math.pi/2

# ─────────────────────────────────────────────────────────────
# 2. Transformations with augmentation for training data
# ─────────────────────────────────────────────────────────────
# Training transform includes augmentation techniques.
train_transform = transforms.Compose([
    # Resize to a slightly bigger image then randomly crop back to IMG_SIZE
    transforms.Resize((IMG_SIZE + 4, IMG_SIZE + 4)),
    transforms.RandomCrop((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    # You can add further augmentation like RandomRotation if desired, for example:
    # transforms.RandomRotation(degrees=15),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor()
])

# Testing transform is kept plain.
test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor()
])

# ─────────────────────────────────────────────────────────────
# 3. Dataset & loaders using custom subsets for different transforms
# ─────────────────────────────────────────────────────────────
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Load the full dataset WITHOUT assigning a transform.
full_ds = datasets.ImageFolder(DATA_DIR)

# Create a custom dataset class to allow different transforms
class AugmentedSubset(torch.utils.data.Dataset):
    def __init__(self, dataset, indices, transform):
        self.dataset = dataset
        self.indices = indices
        self.transform = transform

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        img, label = self.dataset[self.indices[idx]]
        if self.transform:
            img = self.transform(img)
        return img, label

# Split dataset indices into train and test
num_total = len(full_ds)
num_train = int(0.8 * num_total)
indices = list(range(num_total))
random.shuffle(indices)
train_indices = indices[:num_train]
test_indices  = indices[num_train:]

# Create training and test subsets with respective transforms
train_ds = AugmentedSubset(full_ds, train_indices, transform=train_transform)
test_ds  = AugmentedSubset(full_ds, test_indices, transform=test_transform)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False)

print(f'Loaded {len(train_ds)} training and {len(test_ds)} test images.')
print('Classes mapping:', full_ds.classes)   # e.g. ['calculus', 'gingivitis']

# ─────────────────────────────────────────────────────────────
# 4. Hybrid quantum block
# ─────────────────────────────────────────────────────────────
class QuantumCircuitWrapper:
    def __init__(self, n_qubits, backend, shots):
        self.theta = Parameter('θ')
        qc = QiskitCircuit(n_qubits, n_qubits)
        for q in range(n_qubits):
            qc.h(q)
            qc.ry(self.theta, q)
        qc.measure(range(n_qubits), range(n_qubits))
        self.circuit = qc
        self.backend = backend
        self.shots   = shots

    def run(self, theta_val):
        bound = self.circuit.assign_parameters({self.theta: theta_val})
        job   = self.backend.run(bound, shots=self.shots)
        counts = job.result().get_counts()
        exp_z  = 0
        if counts:
            probs = {k: v / self.shots for k, v in counts.items()}
            exp_z = sum(((-1) ** int(bit)) * p for bit, p in probs.items())
        return exp_z

class HybridFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, input, qc, shift):
        theta = input.item()
        ctx.qc, ctx.shift = qc, shift
        exp_val = qc.run(theta)
        ctx.save_for_backward(input, torch.tensor(exp_val))
        return torch.tensor([exp_val], dtype=torch.float32)

    @staticmethod
    def backward(ctx, grad_output):
        (input, _) = ctx.saved_tensors
        theta, shift, qc = input.item(), ctx.shift, ctx.qc
        grad = (qc.run(theta + shift) - qc.run(theta - shift)) / (2 * shift)
        return grad_output * torch.tensor([grad]), None, None

class HybridLayer(nn.Module):
    def __init__(self):
        super().__init__()
        backend = Aer.get_backend('aer_simulator')
        self.qc = QuantumCircuitWrapper(1, backend, SHOTS)

    def forward(self, x):
        return HybridFunction.apply(x, self.qc, SHIFT)

# ─────────────────────────────────────────────────────────────
# 5. CNN + Hybrid network (fc1 size resolves automatically)
# ─────────────────────────────────────────────────────────────
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1   = nn.Conv2d(1, 6, kernel_size=5)
        self.conv2   = nn.Conv2d(6, 16, kernel_size=5)
        self.dropout = nn.Dropout2d()

        # Compute flattened size dynamically.
        with torch.no_grad():
            dummy = torch.zeros(1, 1, IMG_SIZE, IMG_SIZE)
            out   = F.max_pool2d(F.relu(self.conv1(dummy)), 2)
            out   = F.max_pool2d(F.relu(self.conv2(out)), 2)
            self.flatten_dim = out.numel()

        self.fc1    = nn.Linear(self.flatten_dim, 64)
        self.fc2    = nn.Linear(64, 1)
        self.hybrid = HybridLayer()

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = self.dropout(x).view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        # Batch-wise hybrid execution
        outs = [self.hybrid(xi) for xi in x]
        x = torch.stack(outs)           # shape [B, 1]
        x = torch.cat((x, 1 - x), dim=1)
        return F.log_softmax(x, dim=1)

# ─────────────────────────────────────────────────────────────
# 6. Train / evaluate helpers
# ─────────────────────────────────────────────────────────────
def train_epoch(model, loader, opt, criterion):
    model.train(); losses = []
    for data, target in loader:
        opt.zero_grad()
        loss = criterion(model(data), target)
        loss.backward(); opt.step()
        losses.append(loss.item())
    return np.mean(losses)

def evaluate(model, loader, criterion):
    model.eval(); losses, correct = [], 0
    with torch.no_grad():
        for data, target in loader:
            output = model(data)
            losses.append(criterion(output, target).item())
            pred = output.argmax(dim=1)
            correct += pred.eq(target).sum().item()
    return np.mean(losses), correct / len(loader.dataset) * 100

# ─────────────────────────────────────────────────────────────
# 7. Run training loop
# ─────────────────────────────────────────────────────────────
device    = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model     = Net().to(device)
optimizer = optim.Adam(model.parameters(), lr=LR)
criterion = nn.NLLLoss()

train_curve, test_curve = [], []
for epoch in range(1, EPOCHS + 1):
    tr_loss = train_epoch(model, train_loader, optimizer, criterion)
    te_loss, te_acc = evaluate(model, test_loader, criterion)
    train_curve.append(tr_loss); test_curve.append(te_loss)
    print(f'Epoch {epoch:02d}/{EPOCHS} │ '
          f'Train loss {tr_loss:.4f} │ Test loss {te_loss:.4f} │ Acc {te_acc:.1f}%')

# ─────────────────────────────────────────────────────────────
# 8. Plot convergence
# ─────────────────────────────────────────────────────────────
plt.plot(train_curve, label='train')
plt.plot(test_curve,  label='test')
plt.legend(); plt.xlabel('epoch'); plt.ylabel('NLL loss'); plt.title('Augmented Training');
plt.show()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 64.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 44.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 MB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.0/109.0 kB 2.8 MB/s eta 0:00:00
# Mounted at /content/drive
# Loaded 2916 training and 729 test images.
# Classes mapping: ['Calculus', 'Gingivitis']
# Epoch 01/70 │ Train loss 0.6493 │ Test loss 0.6607 │ Acc 63.2%
# Epoch 02/70 │ Train loss 0.6375 │ Test loss 0.6558 │ Acc 63.0%
# Epoch 03/70 │ Train loss 0.6355 │ Test loss 0.6558 │ Acc 62.7%
# Epoch 04/70 │ Train loss 0.6338 │ Test loss 0.6601 │ Acc 63.6%
# Epoch 05/70 │ Train loss 0.6261 │ Test loss 0.6427 │ Acc 65.6%
# Epoch 06/70 │ Train loss 0.6241 │ Test loss 0.6415 │ Acc 66.0%
# Epoch 07/70 │ Train loss 0.6160 │ Test loss 0.6298 │ Acc 66.9%
# Epoch 08/70 │ Train loss 0.6132 │ Test loss 0.6375 │ Acc 64.5%
# Epoch 09/70 │ Train loss 0.6139 │ Test loss 0.6239 │ Acc 66.1%
# Epoch 10/70 │ Train loss 0.6157 │ Test loss 0.6224 │ Acc 65.8%
# Epoch 11/70 │ Train loss 0.6115 │ Test loss 0.6144 │ Acc 67.2%
# Epoch 12/70 │ Train loss 0.6114 │ Test loss 0.6125 │ Acc 66.5%
# Epoch 13/70 │ Train loss 0.6018 │ Test loss 0.6241 │ Acc 66.4%
# Epoch 14/70 │ Train loss 0.5999 │ Test loss 0.5987 │ Acc 68.0%
# Epoch 15/70 │ Train loss 0.5979 │ Test loss 0.6053 │ Acc 67.6%
# Epoch 16/70 │ Train loss 0.5917 │ Test loss 0.5953 │ Acc 66.7%
# Epoch 17/70 │ Train loss 0.5941 │ Test loss 0.5947 │ Acc 68.4%
# Epoch 18/70 │ Train loss 0.5914 │ Test loss 0.5957 │ Acc 69.1%
# Epoch 19/70 │ Train loss 0.5889 │ Test loss 0.5950 │ Acc 68.4%
# Epoch 20/70 │ Train loss 0.5819 │ Test loss 0.5848 │ Acc 70.4%
# Epoch 21/70 │ Train loss 0.5884 │ Test loss 0.5975 │ Acc 68.6%
# Epoch 22/70 │ Train loss 0.5784 │ Test loss 0.5932 │ Acc 69.5%
# Epoch 23/70 │ Train loss 0.5763 │ Test loss 0.5781 │ Acc 69.8%
# Epoch 24/70 │ Train loss 0.5772 │ Test loss 0.5810 │ Acc 70.2%
# Epoch 25/70 │ Train loss 0.5678 │ Test loss 0.5802 │ Acc 70.5%
# Epoch 26/70 │ Train loss 0.5678 │ Test loss 0.5682 │ Acc 72.0%
# Epoch 27/70 │ Train loss 0.5694 │ Test loss 0.5860 │ Acc 69.3%
# Epoch 28/70 │ Train loss 0.5631 │ Test loss 0.5895 │ Acc 69.3%
# Epoch 29/70 │ Train loss 0.5670 │ Test loss 0.5757 │ Acc 70.1%
# Epoch 30/70 │ Train loss 0.5672 │ Test loss 0.5769 │ Acc 70.6%
# Epoch 31/70 │ Train loss 0.5617 │ Test loss 0.5617 │ Acc 70.1%
# Epoch 32/70 │ Train loss 0.5575 │ Test loss 0.5557 │ Acc 72.3%
# Epoch 33/70 │ Train loss 0.5612 │ Test loss 0.5589 │ Acc 70.6%
# Epoch 34/70 │ Train loss 0.5593 │ Test loss 0.5629 │ Acc 71.5%
# Epoch 35/70 │ Train loss 0.5497 │ Test loss 0.5700 │ Acc 71.1%
# Epoch 36/70 │ Train loss 0.5508 │ Test loss 0.5629 │ Acc 70.4%
# Epoch 37/70 │ Train loss 0.5458 │ Test loss 0.5555 │ Acc 71.5%
# Epoch 38/70 │ Train loss 0.5494 │ Test loss 0.5546 │ Acc 71.3%
# Epoch 39/70 │ Train loss 0.5388 │ Test loss 0.5290 │ Acc 73.9%
# Epoch 40/70 │ Train loss 0.5362 │ Test loss 0.5468 │ Acc 71.5%
# Epoch 41/70 │ Train loss 0.5438 │ Test loss 0.5399 │ Acc 73.4%
# Epoch 42/70 │ Train loss 0.5477 │ Test loss 0.5407 │ Acc 73.0%
# Epoch 43/70 │ Train loss 0.5483 │ Test loss 0.5281 │ Acc 73.7%
# Epoch 44/70 │ Train loss 0.5331 │ Test loss 0.5224 │ Acc 74.2%
# Epoch 45/70 │ Train loss 0.5338 │ Test loss 0.5327 │ Acc 73.7%
# Epoch 46/70 │ Train loss 0.5391 │ Test loss 0.5249 │ Acc 73.3%
# Epoch 47/70 │ Train loss 0.5352 │ Test loss 0.5345 │ Acc 73.1%
# Epoch 48/70 │ Train loss 0.5340 │ Test loss 0.5284 │ Acc 73.8%
# Epoch 49/70 │ Train loss 0.5317 │ Test loss 0.5269 │ Acc 73.7%
# Epoch 50/70 │ Train loss 0.5401 │ Test loss 0.5231 │ Acc 75.3%
# Epoch 51/70 │ Train loss 0.5358 │ Test loss 0.5419 │ Acc 72.2%
# Epoch 52/70 │ Train loss 0.5302 │ Test loss 0.5364 │ Acc 73.5%
# Epoch 53/70 │ Train loss 0.5381 │ Test loss 0.5325 │ Acc 73.9%
# Epoch 54/70 │ Train loss 0.5239 │ Test loss 0.5266 │ Acc 73.8%
# Epoch 55/70 │ Train loss 0.5266 │ Test loss 0.5184 │ Acc 74.1%
# Epoch 56/70 │ Train loss 0.5267 │ Test loss 0.5469 │ Acc 71.3%
# Epoch 57/70 │ Train loss 0.5183 │ Test loss 0.5203 │ Acc 74.9%
# Epoch 58/70 │ Train loss 0.5252 │ Test loss 0.5179 │ Acc 74.1%
# Epoch 59/70 │ Train loss 0.5185 │ Test loss 0.5215 │ Acc 73.3%
# Epoch 60/70 │ Train loss 0.5129 │ Test loss 0.5185 │ Acc 74.3%
# Epoch 61/70 │ Train loss 0.5152 │ Test loss 0.5376 │ Acc 73.8%
# Epoch 62/70 │ Train loss 0.5240 │ Test loss 0.5141 │ Acc 75.7%
# Epoch 63/70 │ Train loss 0.5157 │ Test loss 0.5085 │ Acc 75.0%
# Epoch 64/70 │ Train loss 0.5176 │ Test loss 0.5034 │ Acc 74.8%
# Epoch 65/70 │ Train loss 0.5104 │ Test loss 0.5084 │ Acc 75.3%
# Epoch 66/70 │ Train loss 0.5214 │ Test loss 0.5164 │ Acc 73.3%
# Epoch 67/70 │ Train loss 0.5160 │ Test loss 0.5082 │ Acc 74.3%
# Epoch 68/70 │ Train loss 0.5140 │ Test loss 0.5082 │ Acc 75.4%
# Epoch 69/70 │ Train loss 0.5091 │ Test loss 0.5034 │ Acc 75.3%
# Epoch 70/70 │ Train loss 0.5056 │ Test loss 0.5096 │ Acc 75.6%
