# %%
# Mount Google Drive (for Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import required packages
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score

# %%
# Define parameters and dataset directory
batch_size = 32
img_height, img_width = 32, 32
dataset_dir = '/content/drive/MyDrive/Colab Notebooks/data'  # Update path if needed

# %%
# Load the raw training and test datasets using image_dataset_from_directory
raw_train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

raw_test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

# Capture the class names for visualization later
class_names = raw_train_dataset.class_names
# Out:
# Found 3645 files belonging to 2 classes.
# Using 2916 files for training.
# Found 3645 files belonging to 2 classes.
# Using 729 files for validation.

# %%
# Define a function to introduce heavy label noise (70%) and normalize the images.
def add_label_noise(x, y, noise_factor=0.7):
    # Create a noise tensor for each label in the batch
    noise = tf.random.uniform(shape=tf.shape(y), minval=0, maxval=1, dtype=tf.float32)
    # Generate random labels for the entire batch (matching the shape of y)
    random_labels = tf.random.uniform(shape=tf.shape(y), minval=0, maxval=2, dtype=tf.int64)
    # Replace with random label when noise < noise_factor, else keep the original label.
    noisy_y = tf.where(noise < noise_factor, random_labels, tf.cast(y, tf.int64))
    return x / 255.0, noisy_y

# Apply label noise to the training dataset; keep test dataset clean (only normalization)
train_dataset = raw_train_dataset.map(lambda x, y: add_label_noise(x, y, noise_factor=0.7))
test_dataset = raw_test_dataset.map(lambda x, y: (x / 255.0, y))

# %%
# Define a simplified CNN architecture with dropout to reduce capacity
model = models.Sequential([
    layers.Conv2D(16, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),
    layers.Flatten(),
    layers.Dense(16, activation='relu'),
    layers.Dense(2)  # For 2 classes (e.g., "Calculus" and "Gingivitis")
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │        18,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,570 (92.07 KB)
#  Trainable params: 23,570 (92.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model (using 1 epoch here for demonstration; adjust to 80 epochs as needed)
history = model.fit(train_dataset, epochs=80, validation_data=test_dataset)
# Out:
# Epoch 1/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 557s 6s/step - accuracy: 0.5215 - loss: 0.7145 - val_accuracy: 0.6543 - val_loss: 0.6865
# Epoch 2/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 27s 219ms/step - accuracy: 0.5520 - loss: 0.6887 - val_accuracy: 0.6543 - val_loss: 0.6775
# Epoch 3/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 196ms/step - accuracy: 0.5353 - loss: 0.6912 - val_accuracy: 0.6543 - val_loss: 0.6817
# Epoch 4/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 23s 221ms/step - accuracy: 0.5570 - loss: 0.6887 - val_accuracy: 0.6543 - val_loss: 0.6816
# Epoch 5/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 218ms/step - accuracy: 0.5481 - loss: 0.6884 - val_accuracy: 0.6543 - val_loss: 0.6701
# Epoch 6/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 199ms/step - accuracy: 0.5445 - loss: 0.6892 - val_accuracy: 0.6543 - val_loss: 0.6759
# Epoch 7/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 218ms/step - accuracy: 0.5555 - loss: 0.6882 - val_accuracy: 0.6543 - val_loss: 0.6779
# Epoch 8/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 219ms/step - accuracy: 0.5385 - loss: 0.6906 - val_accuracy: 0.6543 - val_loss: 0.6746
# Epoch 9/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 221ms/step - accuracy: 0.5568 - loss: 0.6867 - val_accuracy: 0.6543 - val_loss: 0.6857
# Epoch 10/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 211ms/step - accuracy: 0.5667 - loss: 0.6876 - val_accuracy: 0.6543 - val_loss: 0.6800
# Epoch 11/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 207ms/step - accuracy: 0.5313 - loss: 0.6921 - val_accuracy: 0.6543 - val_loss: 0.6720
# Epoch 12/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 204ms/step - accuracy: 0.5490 - loss: 0.6878 - val_accuracy: 0.6543 - val_loss: 0.6760
# Epoch 13/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s
80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 208ms/step - accuracy: 0.5539 - loss: 0.6868 - val_accuracy: 0.7243 - val_loss: 0.6497
# Epoch 67/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 213ms/step - accuracy: 0.5703 - loss: 0.6812 - val_accuracy: 0.7106 - val_loss: 0.6367
# Epoch 68/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 221ms/step - accuracy: 0.5785 - loss: 0.6806 - val_accuracy: 0.7064 - val_loss: 0.6368
# Epoch 69/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 194ms/step - accuracy: 0.5765 - loss: 0.6760 - val_accuracy: 0.6968 - val_loss: 0.6207
# Epoch 70/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 192ms/step - accuracy: 0.5595 - loss: 0.6847 - val_accuracy: 0.7257 - val_loss: 0.6443
# Epoch 71/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 209ms/step - accuracy: 0.5706 - loss: 0.6743 - val_accuracy: 0.7010 - val_loss: 0.6414
# Epoch 72/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 193ms/step - accuracy: 0.5508 - loss: 0.6856 - val_accuracy: 0.7092 - val_loss: 0.6643
# Epoch 73/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - accuracy: 0.5567 - loss: 0.6842 - val_accuracy: 0.7215 - val_loss: 0.6584
# Epoch 74/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 208ms/step - accuracy: 0.5649 - loss: 0.6812 - val_accuracy: 0.7119 - val_loss: 0.6671
# Epoch 75/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 224ms/step - accuracy: 0.5538 - loss: 0.6840 - val_accuracy: 0.6914 - val_loss: 0.6344
# Epoch 76/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 19s 211ms/step - accuracy: 0.5815 - loss: 0.6761 - val_accuracy: 0.7325 - val_loss: 0.6538
# Epoch 77/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 18s 198ms/step - accuracy: 0.5607 - loss: 0.6823 - val_accuracy: 0.7421 - val_loss: 0.6496
# Epoch 78/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.5568 - loss: 0.6854 - val_accuracy: 0.7064 - val_loss: 0.6336
# Epoch 79/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 21s 221ms/step - accuracy: 0.5489 - loss: 0.6838 - val_accuracy: 0.7435 - val_loss: 0.6418
# Epoch 80/80
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.5468 - loss: 0.6907 - val_accuracy: 0.7078 - val_loss: 0.6365

# %%
# Plot training and validation accuracy over epochs
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Evaluate the model using the built-in evaluate() method
test_loss, test_acc = model.evaluate(test_dataset, verbose=2)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)

# Calculate additional evaluation metrics: Accuracy, Macro-F1, Precision, Recall, AUROC.
all_labels = []
all_preds = []
all_probs = []

for images, labels in test_dataset:
    logits = model.predict(images)
    # Convert logits to probabilities using softmax
    probs = tf.nn.softmax(logits, axis=1).numpy()
    preds = np.argmax(probs, axis=1)

    all_labels.extend(labels.numpy())
    all_preds.extend(preds)
    all_probs.extend(probs)

all_labels = np.array(all_labels)
all_preds = np.array(all_preds)
all_probs = np.array(all_probs)

accuracy_val = accuracy_score(all_labels, all_preds)
macro_f1 = f1_score(all_labels, all_preds, average='macro')
precision_val = precision_score(all_labels, all_preds, average='macro')
recall_val = recall_score(all_labels, all_preds, average='macro')
# For AUROC, use the probability for the positive class (assumed index 1)
auroc_val = roc_auc_score(all_labels, all_probs[:, 1])

print(f"\nCalculated Test Accuracy: {accuracy_val:.4f}")
print(f"Macro F1 Score: {macro_f1:.4f}")
print(f"Precision: {precision_val:.4f}")
print(f"Recall: {recall_val:.4f}")
print(f"AUROC: {auroc_val:.4f}")
# Out:
# 23/23 - 5s - 196ms/step - accuracy: 0.7078 - loss: 0.6365
# Test Loss: 0.6364763379096985
# Test Accuracy: 0.7078189253807068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
#
# Calculated Test Accuracy: 0.7078
# Macro F1 Score: 0.5667
# Precision: 0.7586
# Recall: 0.5877
# AUROC: 0.7978
