# %%
# Md. Shakhawat Hossain
# Bachelor of Science in Computer Science and Engineering (BSCSE)
# Department of Electrical and Computer Engineering
# North South University
# Plot # 15, Block # B, Bashundhara
# Dhaka – 1229, Bangladesh
# Gmail: shakhawat.hossain07.edu@gmail.com

import matplotlib.pyplot as plt
import numpy as np

# Example simulated accuracy results from multiple runs
hqcnn_accuracies = np.array([87.5, 88.0, 88.7, 89.0, 90.0])
qcnn_accuracies  = np.array([67.0, 68.0, 68.7, 69.0, 70.0])

# Combine data into a list for boxplotting
data = [hqcnn_accuracies, qcnn_accuracies]

plt.figure(figsize=(8, 6))
plt.boxplot(data, labels=['HQCNN', 'QCNN'], patch_artist=True)
plt.ylabel('Accuracy (%)')
plt.title('Box and Whisker Plot of Model Accuracy for Binary Classification')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-1-9ef5c1fd43ef>:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['HQCNN', 'QCNN'], patch_artist=True)
